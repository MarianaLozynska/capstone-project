# %%
import numpy as np

# %%
base = "../initial_data"
inputs = {}
outputs = {}

for i in range(1, 9):
    folder = f"{base}/function_{i}"
    inputs[i] = np.load(f"{folder}/initial_inputs.npy")
    outputs[i] = np.load(f"{folder}/initial_outputs.npy")
    
    print(f"Function {i}: inputs = {inputs[i].shape}, outputs = {outputs[i].shape}")
# Out:
# Function 1: inputs = (10, 2), outputs = (10,)
# Function 2: inputs = (10, 2), outputs = (10,)
# Function 3: inputs = (15, 3), outputs = (15,)
# Function 4: inputs = (30, 4), outputs = (30,)
# Function 5: inputs = (20, 4), outputs = (20,)
# Function 6: inputs = (20, 5), outputs = (20,)
# Function 7: inputs = (30, 6), outputs = (30,)
# Function 8: inputs = (40, 8), outputs = (40,)

# %%
week1_inputs = {
    1: np.array([0.4, 0.4]),
    2: np.array([0.72, 0.90]),
    3: np.array([0.51, 0.63, 0.32]),
    4: np.array([0.60, 0.45, 0.41, 0.27]),
    5: np.array([0.24, 0.83, 0.90, 0.90]),
    6: np.array([0.75, 0.17, 0.71, 0.67, 0.08]),
    7: np.array([0.08, 0.47, 0.27, 0.24, 0.44, 0.76]),
    8: np.array([0.07, 0.08, 0.04, 0.06, 0.42, 0.82, 0.51, 0.88])
}
week1_outputs = {
    1: np.float64(0.09787028091182691),
    2: np.float64(0.5567314070917742),
    3: np.float64(-0.05929363571874033),
    4: np.float64(-4.416289141043837),
    5: np.float64(1231.606836011881),
    6: np.float64(-0.5919788840023106),
    7: np.float64(1.364636869415445),
    8: np.float64(9.58626)
}

# %%
combined_inputs = {}
combined_outputs = {}

for i in range(1, 9):
    combined_inputs[i] = np.vstack([inputs[i], week1_inputs[i]])
    combined_outputs[i] = np.append(outputs[i], week1_outputs[i])

# %%
for i in range(1, 9):
    np.save(f"week2_inputs_f{i}.npy", combined_inputs[i])
    np.save(f"week2_outputs_f{i}.npy", combined_outputs[i])

# %%
for i in range(1, 9):
    print(f"\nFunction {i}:")
    print("Inputs shape:", combined_inputs[i].shape)
    print("Outputs shape:", combined_outputs[i].shape)
    print("Last input added:", combined_inputs[i][-1])
    print("Last output added:", combined_outputs[i][-1])
# Out:
# Function 1:
# Inputs shape: (20, 2)
# Outputs shape: (20,)
# Last input added: [0.88388983 0.58225397]
# Last output added: 6.229856468168659e-48
#
# Function 2:
# Inputs shape: (20, 2)
# Outputs shape: (20,)
# Last input added: [0.70263656 0.9265642 ]
# Last output added: 0.6112052157614438
#
# Function 3:
# Inputs shape: (30, 3)
# Outputs shape: (30,)
# Last input added: [0.96599485 0.86111969 0.56682913]
# Last output added: -0.05675837155397648
#
# Function 4:
# Inputs shape: (60, 4)
# Outputs shape: (60,)
# Last input added: [0.8548108  0.49396462 0.73530997 0.80809201]
# Last output added: -23.139428397634813
#
# Function 5:
# Inputs shape: (40, 4)
# Outputs shape: (40,)
# Last input added: [0.12688467 0.15342962 0.77016219 0.19051811]
# Last output added: 9.972331894593824
#
# Function 6:
# Inputs shape: (40, 5)
# Outputs shape: (40,)
# Last input added: [0.12667892 0.2914703  0.06452848 0.6805146  0.89281919]
# Last output added: -1.7468820870493065
#
# Function 7:
# Inputs shape: (60, 6)
# Outputs shape: (60,)
# Last input added: [0.47682313 0.34094195 0.01433523 0.88013956 0.9986547  0.07966402]
# Last output added: 0.0954111589101041
#
# Function 8:
# Inputs shape: (80, 8)
# Outputs shape: (80,)
# Last input added: [0.48124533 0.10246072 0.21948594 0.67732237 0.24750919 0.24434086
#  0.16382453 0.71596164]
# Last output added: 9.1830052453254
